# %% [markdown]
# # What in the world is a Vector Embedding?

# %%
! pip install azure-identity
! pip install openai
! pip install python-dotenv
! pip install numpy pandas
# Out:
# Requirement already satisfied: azure-identity in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (1.15.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from azure-identity) (1.29.7)
# Requirement already satisfied: cryptography>=2.5 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from azure-identity) (42.0.0)
# Requirement already satisfied: msal<2.0.0,>=1.24.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from azure-identity) (1.26.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from azure-identity) (1.1.0)
# Requirement already satisfied: requests>=2.21.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity) (4.9.0)
# Requirement already satisfied: cffi>=1.12 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from cryptography>=2.5->azure-identity) (1.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2.0.0,>=1.24.0->azure-identity) (2.8.0)
# Requirement already satisfied: packaging in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity) (23.2)
# Requirement already satisfied: portalocker<3,>=1.6 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity) (2.8.2)
# Requirement already satisfied: pycparser in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: pywin32>=226 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from portalocker<3,>=1.6->msal-extensions<2.0.0,>=0.3.0->azure-identity) (306)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity) (2023.11.17)
# Requirement already satisfied: openai in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from openai) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from openai) (2.5.3)
# Requirement already satisfied: sniffio in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: certifi in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.14.6)
# Requirement already satisfied: colorama in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: python-dotenv in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (1.26.3)
# Requirement already satisfied: pandas in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\dev\msaitour-azure-vector-samples\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from dotenv import load_dotenv
from openai import AzureOpenAI

# Set up OpenAI client based on environment variables
load_dotenv()
AZURE_OPENAI_ENDPOINT: str = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_KEY: str = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_API_VERSION: str = "2023-05-15"
AZURE_OPENAI_EMBEDDING_DEPLOYED_MODEL_NAME: str = os.getenv(
    "AZURE_OPENAI_EMBEDDING_DEPLOYED_MODEL_NAME"
)


credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(
    credential, "https://cognitiveservices.azure.com/.default"
)

# Set this flag to True if you are using Azure Active Directory
use_aad_for_aoai = True

if use_aad_for_aoai:
    # Use Azure Active Directory (AAD) authentication
    client = AzureOpenAI(
        azure_endpoint=AZURE_OPENAI_ENDPOINT,
        api_version=AZURE_OPENAI_API_VERSION,
        azure_ad_token_provider=token_provider,
    )
else:
    # Use API key authentication
    client = AzureOpenAI(
        api_key=AZURE_OPENAI_API_KEY,
        api_version=AZURE_OPENAI_API_VERSION,
        azure_endpoint=AZURE_OPENAI_ENDPOINT,
    )


# Example function to generate document embedding
def generate_embedding(text: str):
    # Generate embeddings for the provided text using the specified model
    embeddings_response = client.embeddings.create(
        model=AZURE_OPENAI_EMBEDDING_DEPLOYED_MODEL_NAME, input=text
    )
    # Extract the embedding data from the response
    return embeddings_response.data[0].embedding

# %%
# Generate an embedding for the provided text
generate_embedding("The NY Knicks are going to win the NBA Finals this year!")
# Out:
# [-0.0022307680919766426,
#  -0.015993472188711166,
#  -0.0035352003760635853,
#  -0.02250933274626732,
#  -0.018211638554930687,
#  -0.0002172084350604564,
#  -0.015199471265077591,
#  -0.01590524986386299,
#  -0.005400475580245256,
#  0.0036832881160080433,
#  0.03296999633312225,
#  0.007851799950003624,
#  0.003491088980808854,
#  0.0002471410552971065,
#  0.003935352433472872,
#  -0.025017371401190758,
#  0.03304561600089073,
#  -0.012691432610154152,
#  0.029264653101563454,
#  -0.029995638877153397,
#  -0.0029050398152321577,
#  0.015048231929540634,
#  0.01795957423746586,
#  0.002101585268974304,
#  0.004354408942162991,
#  -0.015514550730586052,
#  0.022736189886927605,
#  0.010819855146110058,
#  0.01766970008611679,
#  0.03654930740594864,
#  ...]

# %% [markdown]
# # Document similarity modeled as cosine distance

# %%
import numpy as np


def cosine_similarity(vec_a, vec_b):
    """Calculate the cosine similarity between two vectors."""
    return np.dot(vec_a, vec_b) / (np.linalg.norm(vec_a) * np.linalg.norm(vec_b))


# Example sentences to compare.   
ny_sentences = [  
    "The Empire State Building lights up the Manhattan skyline.",  
    "The Empire State Building lights up the Manhattan skyline.",  
    "The Empire State Building lights up the Manhattan skyline.",  
]  
  
# Sentences to compare against, with a mix of related and unrelated topics.  
comparison_sentences = [  
    "A kangaroo hops across the Australian Outback.",  
    "Cherry blossoms bring spring to life in Kyoto, Japan.",  
    "The Empire State Building lights up the Manhattan skyline.",  
]  

embeddings_ny = [generate_embedding(sentence) for sentence in ny_sentences]  
embeddings_comparison = [generate_embedding(sentence) for sentence in comparison_sentences] 

# Calculating and printing the cosine similarity scores.  
for i, (ny, comparison) in enumerate(zip(ny_sentences, comparison_sentences)):  
    similarity_score = cosine_similarity(embeddings_ny[i], embeddings_comparison[i])  
    print(f"NY: {ny}\nComparison: {comparison}\nScore: {similarity_score:.4f}\n")
# Out:
# NY: The Empire State Building lights up the Manhattan skyline.
# Comparison: A kangaroo hops across the Australian Outback.
# Score: 0.7595
#
# NY: The Empire State Building lights up the Manhattan skyline.
# Comparison: Cherry blossoms bring spring to life in Kyoto, Japan.
# Score: 0.8015
#
# NY: The Empire State Building lights up the Manhattan skyline.
# Comparison: The Empire State Building lights up the Manhattan skyline.
# Score: 1.0000

# %% [markdown]
# # Vector Search

# %%
import json  
  
# Initialize an empty list to hold all the vectors  
dbpedia_vectors = []  
  
# Load in vectors for Wikipedia articles from a .jsonl file  
with open('dbpedia_samples_embeddings.jsonl', 'r', encoding='utf-8') as json_file:  
    for line in json_file:  
        # Each line is a separate JSON object  
        dbpedia_vectors.append(json.loads(line))

# %%
import numpy as np  
import pandas as pd  
  
# Sample query  
query = "notable educational instituions"  
  
# Generate embedding for the query  
query_vector = generate_embedding(query)  
query_vector = np.array(query_vector)  
  
# Calculate the cosine similarity between the query and each vector  
similarity_scores = [cosine_similarity(query_vector, np.array(article['vector'])) for article in dbpedia_vectors]  
  
# Assuming you want to also capture the text associated with each vector  
results = [(article['text'], score) for article, score in zip(dbpedia_vectors, similarity_scores)]  
  
# Create a DataFrame to display the results  
df = pd.DataFrame(results, columns=['Text', 'Similarity Score'])  
  
# Sort the DataFrame by the similarity score in descending order  
df_sorted = df.sort_values(by='Similarity Score', ascending=False)  
  
# Display the top results  
print(df_sorted.head())
# Out:
#                                                   Text  Similarity Score
# 123   Blackburn High School is a public secondary s...          0.770751
# 157   Michael E. DeBakey High School for Health Pro...          0.769030
# 121   Grand Canyon Preparatory Academy is a public ...          0.757726
# 101   The Chiltern School is a coeducational specia...          0.753215
# 155   The University of Nevada School of Medicine i...          0.748609
